# %% [markdown]
# <a href="https://colab.research.google.com/github/diego40g/data_science_python/blob/numpy/200_spectroChemp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install spectrochempy &>> output.log
exit()

# %%
import spectrochempy as scp
# %matplotlib inline
# Out:
#
#     <div>
#     <table>
#     <tr>
#     <td>
#
#     <img src='...'
#          style='height:25px; border-radius:12px; display:inline-block; float:left; vertical-align:middle'>
#     </img>
#
#     </td>
#     <td>
#
#     &nbsp;&nbsp;<span style='font-size:12px'>SpectroChemPy's API - v.0.4.7<br/>© Copyright 2014-2022 - A.Travert & C.Fernandez @ LCS</span>
#
#     </td>
#     </tr>
#     </table>
#     </div>

# %%
A = scp.random((10,100))
_ = A.plot(method="map")
