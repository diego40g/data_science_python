# %% [markdown]
# <a href="https://colab.research.google.com/github/diego40g/data_science_python/blob/numpy/131_matploit13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.seed(7)

# %%
#dataframe
data = np.random.randint(low = 100, high = [250, 300, 500, 1000], size = (12, 4))
print(data)
# Out:
# [[125 167 311 715]
#  [192 285 498 635]
#  [172 189 466 654]
#  [236 267 168 532]
#  [227 235 100 175]
#  [155 106 375 544]
#  [144 291 425 924]
#  [212 289 390 412]
#  [138 104 237 955]
#  [172 183 357 804]
#  [244 218 449 704]
#  [171 123 110 845]]

# %%
index = pd.date_range(start = '2021-1-1', periods = 12, freq = 'M')
print(index)
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame(data, columns = list('ABCD'), index = index.month_name())
print(df)
# Out:
#              A    B    C    D
# January    125  167  311  715
# February   192  285  498  635
# March      172  189  466  654
# April      236  267  168  532
# May        227  235  100  175
# June       155  106  375  544
# July       144  291  425  924
# August     212  289  390  412
# September  138  104  237  955
# October    172  183  357  804
# November   244  218  449  704
# December   171  123  110  845

# %%
#plot
plt.figure(figsize = (15, 5))
plt.plot(df)
plt.title('Values over time')
plt.legend(df.columns, loc = 'best')
plt.grid(linestyle = '--', alpha = 0.5)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.ylim(80, 1000)
plt.savefig('fig.jpeg')
plt.show()
