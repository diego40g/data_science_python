# %% [markdown]
# <a href="https://colab.research.google.com/github/diego40g/data_science_python/blob/numpy/122_matplot4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
n = 100
print(n)
# Out:
# 100

# %%
columns = ['Brand '+str(number) for number in range(1,5)]
print(columns)
# Out:
# ['Brand 1', 'Brand 2', 'Brand 3', 'Brand 4']

# %%
date = pd.date_range(start = '2021-1-1', periods = n)
print(date)
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15', '2021-01-16',
#                '2021-01-17', '2021-01-18', '2021-01-19', '2021-01-20',
#                '2021-01-21', '2021-01-22', '2021-01-23', '2021-01-24',
#                '2021-01-25', '2021-01-26', '2021-01-27', '2021-01-28',
#                '2021-01-29', '2021-01-30', '2021-01-31', '2021-02-01',
#                '2021-02-02', '2021-02-03', '2021-02-04', '2021-02-05',
#                '2021-02-06', '2021-02-07', '2021-02-08', '2021-02-09',
#                '2021-02-10', '2021-02-11', '2021-02-12', '2021-02-13',
#                '2021-02-14', '2021-02-15', '2021-02-16', '2021-02-17',
#                '2021-02-18', '2021-02-19', '2021-02-20', '2021-02-21',
#                '2021-02-22', '2021-02-23', '2021-02-24', '2021-02-25',
#                '2021-02-26', '2021-02-27', '2021-02-28', '2021-03-01',
#                '2021-03-02', '2021-03-03', '2021-03-04', '2021-03-05',
#                '2021-03-06', '2021-03-07', '2021-03-08', '2021-03-09',
#                '2021-03-10', '2021-03-11', '2021-03-12', '2021-03-13',
#                '2021-03-14', '2021-03-15', '2021-03-16', '2021-03-17',
#                '2021-03-18', '2021-03-19', '2021-03-20', '2021-03-21',
#                '2021-03-22', '2021-03-23', '2021-03-24', '2021-03-25',
#                '2021-03-26', '2021-03-27', '2021-03-28', '2021-03-29',
#                '2021-03-30', '2021-03-31', '2021-04-01', '2021-04-02',
#                '2021-04-03', '2021-04-04', '2021-04-05', '2021-04-06',
#                '2021-04-07', '2021-04-08', '2021-04-09', '2021-04-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
data = np.random.randint(low = 1, high = [100, 330, 45, 77], size = (n, 4))
print(data)
# Out:
# [[ 11 240  19  24]
#  [ 67  24  19  10]
#  [ 60 173   8  13]
#  [ 88 217  24  27]
#  [  1 322  14  48]
#  [ 51 190  33  15]
#  [ 53 259   4  45]
#  [ 87 119  32  35]
#  [ 74  74   7  17]
#  [ 83  25  35  53]
#  [ 32  51  30  32]
#  [  4 117  27  65]
#  [ 69 151  30  27]
#  [ 56 101  33  18]
#  [ 20 160  32  49]
#  [  9  22  12  57]
#  [ 65  15   9  28]
#  [ 83 146  20  75]
#  [ 16  85  17  37]
#  [ 54 154   1  33]
#  [ 71 108  20  38]
#  [ 72  84  29  50]
#  [ 96 170   3  75]
#  [ 99 287  41  31]
#  [ 11 266   3  51]
#  [ 27 267  38  40]
#  [ 96  50   7  60]
#  [ 79 161   3  11]
#  [  6  21   7  63]
#  [ 66 230  24  21]
#  [ 37 216  24  72]
#  [ 94 309  29  31]
#  [ 76 259  34  45]
#  [ 21  22   4  50]
#  [ 28 188   5  36]
#  [ 94 141  44  16]
#  [ 49 301  12  37]
#  [ 97  63  18  27]
#  [ 19 229   8  27]
#  [ 11  61  24  44]
#  [ 40  12  35  38]
#  [ 60  37  14  58]
#  [ 45 189  24  23]
#  [ 52 212  31  56]
#  [ 88 288  21  52]
#  [ 39 191  26  19]
#  [ 48 291  22  41]
#  [ 34  27  25  46]
#  [ 94 118  27  50]
#  [ 19  79  13  30]
#  [ 10 148  21  42]
#  [ 32 284  23   9]
#  [ 76  45   4  39]
#  [ 63 137  38  40]
#  [  5 311  16  49]
#  [ 57 100  28  45]
#  [ 75 300  31  49]
#  [ 96 159  36  38]
#  [  2  62  42  69]
#  [ 23 321  27  67]
#  [ 56 222  17  46]
#  [ 53 104  34  23]
#  [ 51 210  41  50]
#  [  5 274   6  54]
#  [ 87 269   9  36]
#  [ 95 322  28   4]
#  [ 39 183  31  23]
#  [ 44 193  11  51]
#  [ 31  53   3  56]
#  [ 54 250   3  71]
#  [ 71 140  32  51]
#  [ 11 162  11  23]
#  [ 71 106   7  52]
#  [  2  80  20  63]
#  [ 74  33  20  62]
#  [  5 287   4  47]
#  [ 34 191  28  30]
#  [ 89 213  39  34]
#  [ 55 304  11  63]
#  [ 47 112   9  32]
#  [ 30 104  22  67]
#  [ 25 323  42  61]
#  [ 23 185  11  62]
#  [ 14 221   6  40]
#  [ 89  71   5  63]
#  [ 66 168  10  50]
#  [ 54 328  43  26]
#  [ 51 202   1  21]
#  [ 62 283   5  71]
#  [ 33 131  26  36]
#  [ 15  50  30  50]
#  [ 58 250  35  20]
#  [ 13  78  30   9]
#  [ 99 161  44  42]
#  [ 92  92  25  42]
#  [ 77  30  36  18]
#  [  7 101  17  27]
#  [ 96 278  43  27]
#  [ 34 198   2  19]
#  [ 31  90  24  75]]

# %%
df = pd.DataFrame(data,columns = columns, index = date)
print(df)
# Out:
#             Brand 1  Brand 2  Brand 3  Brand 4
# 2021-01-01       11      240       19       24
# 2021-01-02       67       24       19       10
# 2021-01-03       60      173        8       13
# 2021-01-04       88      217       24       27
# 2021-01-05        1      322       14       48
# ...             ...      ...      ...      ...
# 2021-04-06       77       30       36       18
# 2021-04-07        7      101       17       27
# 2021-04-08       96      278       43       27
# 2021-04-09       34      198        2       19
# 2021-04-10       31       90       24       75
#
# [100 rows x 4 columns]

# %%
#plot
plt.figure(figsize = (12, 5))
plt.plot(df.index, df['Brand 1'], c = 'black', ls = '-')
plt.title('Brand A')
plt.xlabel('Time')
plt.ylabel('Values')
plt.grid(True)
