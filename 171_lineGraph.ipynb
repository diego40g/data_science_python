# %% [markdown]
# <a href="https://colab.research.google.com/github/diego40g/data_science_python/blob/numpy/171_lineGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[10,11,12]

# %%
plt.plot(x,y)
plt.title("Gráfico Lineal")
plt.ylabel('Eje Y')
plt.xlabel('Eje X')
# Out:
# Text(0.5, 0, 'Eje X')

# %%
plt.show()
