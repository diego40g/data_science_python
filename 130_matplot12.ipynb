# %% [markdown]
# <a href="https://colab.research.google.com/github/diego40g/data_science_python/blob/numpy/130_matplot12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
sales = [1500.2, 1378, 671, 431, 700]
print(sales)
# Out:
# [1500.2, 1378, 671, 431, 700]

# %%
labels = ['Brand '+str(number) for number in range(1,len(sales)+1)]
print(labels)
# Out:
# ['Brand 1', 'Brand 2', 'Brand 3', 'Brand 4', 'Brand 5']

# %%
explode = (0.1, 0.1, 0, 0, 0)
print(explode)
# Out:
# (0.1, 0.1, 0, 0, 0)

# %%
plt.pie(sales, labels = labels, autopct = '%1.2f%%', explode = explode, shadow = True)
plt.legend(labels, loc = 'upper left')
plt.show()
