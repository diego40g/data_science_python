# %% [markdown]
# <a href="https://colab.research.google.com/github/diego40g/data_science_python/blob/numpy/220_linearGraph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[19,11,12]

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("Grafico de líneas")
plt.ylabel("Eje Y")
plt.xlabel("Eje X")
plt.show()
